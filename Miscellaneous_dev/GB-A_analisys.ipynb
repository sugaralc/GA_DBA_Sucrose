# %%
from rdkit import Chem, DataStructs
from rdkit.Chem.Fraggle import FraggleSim
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit.Chem import rdmolops
from rdkit.Chem.Draw import IPythonConsole, MolsToGridImage
from rdkit.Chem import rdDepictor
from rdkit import RDConfig
from rdkit.Chem import rdFingerprintGenerator
from rdkit.Geometry import Point3D
from rdkit.Chem import rdForceFieldHelpers
from random import randrange
import py3Dmol
import copy

#from rdkit import rdBase
#rdBase.DisableLog('rdApp.error')
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

import xyz2mol as x2m
import os

from neutralize import neutralize_smiles

charged_fragments = True
quick = True

def drawit(ms, p=None, confId=-1, removeHs=True,colors=('cyanCarbon','redCarbon','blueCarbon')):
        if p is None:
            p = py3Dmol.view(width=600, height=600)
        p.removeAllModels()
        for i,m in enumerate(ms):
            if removeHs:
                m = Chem.RemoveHs(m)
            IPythonConsole.addMolToView(m,p,confId=confId)
            p.setStyle({'model':-1,},
                            {'stick':{'colorscheme':colors[i%len(colors)]}})
        p.zoomTo()
        return p.show()

def show_3dmol(image_id=None,inchi=None,smiles=None,mol=None):
    mol = mol
    if not mol:
        print('No molecule is provided')
        return
           
    molh = Chem.AddHs(mol)
    #if AllChem.EmbedMolecule(molh,randomSeed=0xf00d)<0:
    #    print('Failed to embed in 3d')
    #    return
    pdb_data = Chem.MolToPDBBlock(molh)
    view = py3Dmol.view(width=600, height=600, query=None, data=pdb_data, linked=False)
    view.setStyle({'model':-1,},{'stick': {}})
    #view.setBackgroundColor('#f9f4fb')
    return view

# %%
with open("smiles", "r+") as file1:
    # Reading from a file
    smiles = [line.rstrip() for line in file1]
    #print(len(smiles))
    for smile in smiles:
        mol1 = Chem.MolFromSmiles(smile)
        if Chem.GetFormalCharge(mol1) != 0:
            neutral_smiles1 = neutralize_smiles([Chem.MolToSmiles(mol1)])
            mol2 = Chem.MolFromSmiles(neutral_smiles1[0])
            if Chem.GetFormalCharge(mol2) != 0:
                rings = mol2.GetRingInfo().AtomRings()
                rings_info = mol2.GetRingInfo()
                B_smarts = Chem.MolFromSmarts("[#5-]")
                N_smarts = Chem.MolFromSmarts("[#7R1+]")
                N_matchs = mol2.GetSubstructMatches(N_smarts)
                BC_pairs = []
                B_matches = []
                for B_match in mol2.GetSubstructMatches(B_smarts):
                    B_atom = mol2.GetAtomWithIdx(B_match[0])
                    B_matches.append(B_match[0])
                    for neigh in B_atom.GetNeighbors():
                        if neigh.GetAtomicNum() == 6:
                            BC_pairs.append([B_match[0],neigh.GetIdx()])
                BExclude = []
                for BC_pair in BC_pairs:
                    for N_match in N_matchs:
                        if rings_info.AreAtomsInSameRing(BC_pair[1],N_match[0]):
                            BExclude.append(BC_pair[0])
                BO_groups = []
                B_matches.sort(reverse=True)
                for B_match in B_matches:
                    if B_match not in BExclude:
                        B_atom = mol2.GetAtomWithIdx(B_match)
                        O_atoms = []
                        for neigh in B_atom.GetNeighbors():
                            if neigh.GetAtomicNum() == 8:
                                O_atoms.append(neigh.GetIdx())
                        O_atoms.sort(reverse=True)
                        BO_groups.append(O_atoms)
                        
                em = Chem.RWMol(mol2)
                em.BeginBatchEdit()
                i = 0
                for B_match in B_matches:
                    if B_match not in BExclude:
                        Batom = em.GetAtomWithIdx(B_match)
                        Batom.SetFormalCharge(0)
                        em.RemoveAtom(BO_groups[i][0])
                        i += 1
                em.CommitBatchEdit()
                mol3 = em.GetMol()
                if Chem.GetFormalCharge(mol3) != 0:
                    while Chem.GetFormalCharge(mol3) != 0:
                        Cl_anion = Chem.MolFromSmiles("[Cl-]")
                        Na_cation = Chem.MolFromSmiles("[Na+]")
                        if Chem.GetFormalCharge(mol3) < 0:
                            molfrag = Chem.CombineMols(mol3,Na_cation)
                        elif Chem.GetFormalCharge(mol3) > 0:
                            molfrag = Chem.CombineMols(mol3,Cl_anion)
                        mol3 = copy.deepcopy(molfrag)
                    print("Returning neutral mol by adding counter anions",Chem.MolToSmiles(mol3))
                else:
                    print("Returning neutral mol mol3")
            else:
                print("Returning neutral mol mol2")       
        else:
            print("Returning neutral mol mol1")
# Out:
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol by adding counter anions C=CCCS(=O)(=O)c1ccc(B(O)O)c([C@@H]2C=Cc3ccc(-c4cccc(B(O)O)c4)c4c([N+](C)=O)ccc2c34)c1.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=CCCS(=O)(=O)c1ccc(B(O)O)cc1-c1cc2ccccc2c2c1ccc1cc(ON[O-])cc(-c3cc(C(C)=O)ccc3B(O)O)c12.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol2
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol2
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol1
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol2
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC[C@H](C[n+]1cncc(-c2cccc(B(O)O)c2)c1)C1=C(C)c2cc3c(B(O)O)cccc3cc2C1.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC=CC[n+]1c(C)cc(-c2cccc(B(O)O)c2)c2ccc3cccc(-c4cccc(B(O)O)c4)c3c21.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC=CC[n+]1c(C)cc(-c2cccc(B(O)O)c2)c2ccc3cccc(-c4cc(B(O)O)ccc4Br)c3c21.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2ccccc2B(O)O)c2ccc(N([O-])O)c3ccc(-c4cccc(B(O)O)c4)c1c23.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4ccc(C=O)cc4B(O)O)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4cc(B(O)O)ccc4F)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC=c1cc(-c2ccc(B(O)O)cc2F)c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC(C)=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol by adding counter anions COC=c1cc(-c2ccccc2B(O)O)c2cc(C(=O)O)c(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c23.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC=c1cc(-c2cc(B(O)O)cc(N)c2[N+](=O)[O-])c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol by adding counter anions COC=C(C)c1c(-c2cccc(B(O)O)c2)ccc2c(N[O-])ccc(Cc3ccccc3B(O)O)c12.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC=C1Cc2cc(-c3cccc(B(O)O)c3)c3ccc4cccc(-c5cc(B(O)O)ccc5Br)c4c3[n+]2C1.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC=CC[n+]1c(C)cc(-c2cccc(B(O)O)c2)c2cc(C(F)(F)F)c3cccc(-c4cc(B(O)O)ccc4Br)c3c21.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2c(B(O)O)cccc2[N+](=O)[O-])c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4ccc(B(O)O)cn4)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC=CC[n+]1c(C)cc(-c2cccc(B(O)O)c2)c2ccc3cccc(-c4ccc(OC)cc4B(O)O)c3c21.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions CC=CC[n+]1c(C)cc(-c2cccc(B(O)O)c2)c2ccc3cccc(-c4cc(C(=O)NC)ccc4B(O)O)c3c21.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC(C)=c1cc(-c2ccc(B(O)O)cn2)c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol mol1
# Returning neutral mol by adding counter anions CC[N+]1=C(C)C=C(c2cccc(B(O)O)c2)C2=CC=C3C=CC=C(c4cccc(B(O)O)c4)C3C21.[Cl-]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions COC(C)=c1cc(-c2ccncc2B(O)O)c2ccc(N[O-])c3ccc(-c4cccc(B(O)O)c4)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions Cc1cc(-c2cccc(B(O)O)c2)c2ccc3cccc(-c4cccc(B(O)O)c4)c3c2[n+]1CC=CN.[Cl-]
# Returning neutral mol by adding counter anions CC=C(c1cccc(B(O)O)c1)c1c2c(c(-c3ccccc3B(O)O)cc1=COC)=CC(C(=O)O)=C(N[O-])C2.[Na+]
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c4cc(B(O)O)ccc4S(C)(=O)=O)c1c32.[Na+]
# Returning neutral mol mol3
# Returning neutral mol by adding counter anions C=c1cc(-c2ccccc2B(O)O)c2ccc(N[O-])c3ccc(-c